# %% [markdown]
# # LGBM baseline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import lightgbm as lgb
from sklearn.model_selection import GroupKFold
from sklearn.metrics import accuracy_score

pd.set_option('display.max_columns', 500)

# %%
DATA_DIR = '../dataset/raw/'

with open(DATA_DIR + 'features.txt') as f:
    features_txt = f.readlines()

features_name = [x.strip() for x in features_txt]
features_name = ["".join (c if c.isalnum() else "_" for c in str(x)) for x in features_name]

X_train = pd.read_csv(DATA_DIR + 'X_train.csv', names=features_name)
X_test = pd.read_csv(DATA_DIR + 'X_test.csv', names=features_name)
y_train = pd.read_csv(DATA_DIR + 'y_train.csv', names=['activity_label'])
subject_train = pd.read_csv(DATA_DIR + 'subject_train.csv', names=['subject_id'])

# 0始まりにする
y_train['activity_label'] = y_train['activity_label'] - 1
all_df_train = pd.concat([X_train, subject_train, y_train], axis=1)

# %%
def lgb_trainer_with_group_kfold(df_train, df_test, features, target, group, num_folds=15, params=None):
    # data setup
    X_train = df_train[features]
    Y_train = df_train[target]
    X_test = df_test[features]

    # initialize
    valid_preds = np.zeros((len(X_train), 6))
    test_preds = np.zeros((num_folds, len(X_test), 6))
    kf = GroupKFold(n_splits=num_folds)
    importantce_df = pd.DataFrame()
    for fold, (train_index, valid_index) in enumerate(
        kf.split(X=df_train[group], groups=df_train[group])):
        print('Fold {}'.format(fold + 1))
        x_trn, x_val = X_train.iloc[train_index], X_train.iloc[valid_index]
        y_trn, y_val = Y_train.iloc[train_index], Y_train.iloc[valid_index]
        train_set = lgb.Dataset(x_trn, y_trn)
        val_set = lgb.Dataset(x_val, y_val)

        if params is None:
            params = {
                'learning_rate': 0.1,
                'metric': 'rmse',
                'objective': 'regression',
                'feature_fraction': 0.85,
                'subsample': 0.85,
                'n_jobs': -1,
                'seed': 1234,
                'max_depth': -1
            }

        # train the model with early stoping
        model = lgb.train(params, train_set, num_boost_round=10000, early_stopping_rounds=10,
                          valid_sets=[train_set, val_set], verbose_eval=10)
        valid_preds[valid_index] = model.predict(x_val)
        
        # calc score
        score = accuracy_score(y_val, np.argmax(valid_preds[valid_index], axis=1))
        print('Fold {} Score : {}'.format(fold+1, score))
        
        # get feature importance
        feature_imp = pd.DataFrame(
            sorted(zip(model.feature_importance(), features), reverse=True), 
            columns=['Value','Feature']
        )
        importantce_df['Fold {}'.format(fold+1)] = feature_imp['Feature']
        
        # get test predict
        test_preds[fold] = model.predict(X_test)

    return test_preds, importantce_df

# %%
features = X_train.columns
target = ['activity_label']
group = ['subject_id']
params = {
    'learning_rate': 0.1,
    'objective': 'multiclass',
    'num_class': 6,
    'n_jobs': -1,
    'seed': 1234,
}

test_preds, importantce_df = lgb_trainer_with_group_kfold(
    all_df_train, X_test, features, target, group, num_folds=15, params=params)
# Out:
# Fold 1
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.538108	valid_1's multi_logloss: 0.56559
# [20]	training's multi_logloss: 0.204447	valid_1's multi_logloss: 0.236203
# [30]	training's multi_logloss: 0.0813578	valid_1's multi_logloss: 0.106996
# [40]	training's multi_logloss: 0.0330009	valid_1's multi_logloss: 0.0522653
# [50]	training's multi_logloss: 0.0135288	valid_1's multi_logloss: 0.0256936
# [60]	training's multi_logloss: 0.00566862	valid_1's multi_logloss: 0.013603
# [70]	training's multi_logloss: 0.00240061	valid_1's multi_logloss: 0.00757135
# [80]	training's multi_logloss: 0.00103427	valid_1's multi_logloss: 0.00491703
# [90]	training's multi_logloss: 0.000451169	valid_1's multi_logloss: 0.00326127
# [100]	training's multi_logloss: 0.000195308	valid_1's multi_logloss: 0.00242068
# [110]	training's multi_logloss: 8.57059e-05	valid_1's multi_logloss: 0.00189962
# [120]	training's multi_logloss: 3.83693e-05	valid_1's multi_logloss: 0.00145767
# [130]	training's multi_logloss: 1.74189e-05	valid_1's multi_logloss: 0.00122629
# [140]	training's multi_logloss: 8.59543e-06	valid_1's multi_logloss: 0.00104639
# [150]	training's multi_logloss: 4.67691e-06	valid_1's multi_logloss: 0.00094015
# [160]	training's multi_logloss: 2.91284e-06	valid_1's multi_logloss: 0.000857988
# [170]	training's multi_logloss: 2.10674e-06	valid_1's multi_logloss: 0.000739393
# [180]	training's multi_logloss: 1.67438e-06	valid_1's multi_logloss: 0.000694162
# [190]	training's multi_logloss: 1.41986e-06	valid_1's multi_logloss: 0.000679317
# [200]	training's multi_logloss: 1.25112e-06	valid_1's multi_logloss: 0.000657985
# [210]	training's multi_logloss: 1.13252e-06	valid_1's multi_logloss: 0.0006338
# [220]	training's multi_logloss: 1.04155e-06	valid_1's multi_logloss: 0.000612297
# [230]	training's multi_logloss: 9.79866e-07	valid_1's multi_logloss: 0.000578678
# [240]	training's multi_logloss: 9.26868e-07	valid_1's multi_logloss: 0.000562866
# [250]	training's multi_logloss: 8.84443e-07	valid_1's multi_logloss: 0.000570963
# Early stopping, best iteration is:
# [243]	training's multi_logloss: 9.14975e-07	valid_1's multi_logloss: 0.000562146
# Fold 1 Score : 1.0
# Fold 2
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.534318	valid_1's multi_logloss: 0.674057
# [20]	training's multi_logloss: 0.201631	valid_1's multi_logloss: 0.37323
# [30]	training's multi_logloss: 0.0796744	valid_1's multi_logloss: 0.25392
# [40]	training's multi_logloss: 0.0320501	valid_1's multi_logloss: 0.207795
# [50]	training's multi_logloss: 0.0131529	valid_1's multi_logloss: 0.181254
# [60]	training's multi_logloss: 0.00546628	valid_1's multi_logloss: 0.166163
# [70]	training's multi_logloss: 0.002296	valid_1's multi_logloss: 0.160658
# [80]	training's multi_logloss: 0.000979467	valid_1's multi_logloss: 0.151252
# [90]	training's multi_logloss: 0.000419135	valid_1's multi_logloss: 0.148462
# [100]	training's multi_logloss: 0.000182981	valid_1's multi_logloss: 0.14544
# [110]	training's multi_logloss: 8.00093e-05	valid_1's multi_logloss: 0.154312
# Early stopping, best iteration is:
# [100]	training's multi_logloss: 0.000182981	valid_1's multi_logloss: 0.14544
# Fold 2 Score : 0.9354838709677419
# Fold 3
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.536197	valid_1's multi_logloss: 0.618
# [20]	training's multi_logloss: 0.202975	valid_1's multi_logloss: 0.290163
# [30]	training's multi_logloss: 0.0803004	valid_1's multi_logloss: 0.160569
# [40]	training's multi_logloss: 0.0325834	valid_1's multi_logloss: 0.101823
# [50]	training's multi_logloss: 0.0133994	valid_1's multi_logloss: 0.0776198
# [60]	training's multi_logloss: 0.00562244	valid_1's multi_logloss: 0.064445
# [70]	training's multi_logloss: 0.00238443	valid_1's multi_logloss: 0.0563164
# [80]	training's multi_logloss: 0.00102402	valid_1's multi_logloss: 0.0522616
# [90]	training's multi_logloss: 0.000440765	valid_1's multi_logloss: 0.0488069
# [100]	training's multi_logloss: 0.000190828	valid_1's multi_logloss: 0.0495569
# [110]	training's multi_logloss: 8.37621e-05	valid_1's multi_logloss: 0.0475905
# [120]	training's multi_logloss: 3.73087e-05	valid_1's multi_logloss: 0.046289
# [130]	training's multi_logloss: 1.70124e-05	valid_1's multi_logloss: 0.046247
# Early stopping, best iteration is:
# [121]	training's multi_logloss: 3.44219e-05	valid_1's multi_logloss: 0.0457751
# Fold 3 Score : 0.9755434782608695
# Fold 4
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.531879	valid_1's multi_logloss: 0.790183
# [20]	training's multi_logloss: 0.201184	valid_1's multi_logloss: 0.529339
# [30]	training's multi_logloss: 0.0790382	valid_1's multi_logloss: 0.430276
# [40]	training's multi_logloss: 0.0316619	valid_1's multi_logloss: 0.411856
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.0415255	valid_1's multi_logloss: 0.403204
# Fold 4 Score : 0.8879781420765027
# Fold 5
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.534649	valid_1's multi_logloss: 0.761122
# [20]	training's multi_logloss: 0.202996	valid_1's multi_logloss: 0.523066
# [30]	training's multi_logloss: 0.0807071	valid_1's multi_logloss: 0.463698
# [40]	training's multi_logloss: 0.0328555	valid_1's multi_logloss: 0.439306
# [50]	training's multi_logloss: 0.0135146	valid_1's multi_logloss: 0.453604
# Early stopping, best iteration is:
# [42]	training's multi_logloss: 0.0275054	valid_1's multi_logloss: 0.438813
# Fold 5 Score : 0.8681318681318682
# Fold 6
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.536613	valid_1's multi_logloss: 0.700043
# [20]	training's multi_logloss: 0.202808	valid_1's multi_logloss: 0.407482
# [30]	training's multi_logloss: 0.0801245	valid_1's multi_logloss: 0.279573
# [40]	training's multi_logloss: 0.0323423	valid_1's multi_logloss: 0.215552
# [50]	training's multi_logloss: 0.0132773	valid_1's multi_logloss: 0.19749
# [60]	training's multi_logloss: 0.00553204	valid_1's multi_logloss: 0.194991
# [70]	training's multi_logloss: 0.00232943	valid_1's multi_logloss: 0.19728
# Early stopping, best iteration is:
# [62]	training's multi_logloss: 0.00464999	valid_1's multi_logloss: 0.190739
# Fold 6 Score : 0.9265536723163842
# Fold 7
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.53536	valid_1's multi_logloss: 0.625036
# [20]	training's multi_logloss: 0.203253	valid_1's multi_logloss: 0.315797
# [30]	training's multi_logloss: 0.0805436	valid_1's multi_logloss: 0.20347
# [40]	training's multi_logloss: 0.0326139	valid_1's multi_logloss: 0.156582
# [50]	training's multi_logloss: 0.0133337	valid_1's multi_logloss: 0.137353
# [60]	training's multi_logloss: 0.00554825	valid_1's multi_logloss: 0.13123
# [70]	training's multi_logloss: 0.00235992	valid_1's multi_logloss: 0.13291
# Early stopping, best iteration is:
# [66]	training's multi_logloss: 0.00332077	valid_1's multi_logloss: 0.129312
# Fold 7 Score : 0.968299711815562
# Fold 8
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.536874	valid_1's multi_logloss: 0.663367
# [20]	training's multi_logloss: 0.204655	valid_1's multi_logloss: 0.334131
# [30]	training's multi_logloss: 0.0811554	valid_1's multi_logloss: 0.195758
# [40]	training's multi_logloss: 0.0328485	valid_1's multi_logloss: 0.13577
# [50]	training's multi_logloss: 0.0135505	valid_1's multi_logloss: 0.103612
# [60]	training's multi_logloss: 0.00568549	valid_1's multi_logloss: 0.0871357
# [70]	training's multi_logloss: 0.0024177	valid_1's multi_logloss: 0.0805133
# [80]	training's multi_logloss: 0.00102644	valid_1's multi_logloss: 0.0788318
# [90]	training's multi_logloss: 0.000440395	valid_1's multi_logloss: 0.0722478
# [100]	training's multi_logloss: 0.000190484	valid_1's multi_logloss: 0.0745553
# Early stopping, best iteration is:
# [93]	training's multi_logloss: 0.000342537	valid_1's multi_logloss: 0.0703212
# Fold 8 Score : 0.9680232558139535
# Fold 9
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.535998	valid_1's multi_logloss: 0.634753
# [20]	training's multi_logloss: 0.204006	valid_1's multi_logloss: 0.302446
# [30]	training's multi_logloss: 0.0811046	valid_1's multi_logloss: 0.148709
# [40]	training's multi_logloss: 0.0328593	valid_1's multi_logloss: 0.0804191
# [50]	training's multi_logloss: 0.0135756	valid_1's multi_logloss: 0.0509359
# [60]	training's multi_logloss: 0.00566144	valid_1's multi_logloss: 0.0317822
# [70]	training's multi_logloss: 0.00240407	valid_1's multi_logloss: 0.0224411
# [80]	training's multi_logloss: 0.00102994	valid_1's multi_logloss: 0.016963
# [90]	training's multi_logloss: 0.000444861	valid_1's multi_logloss: 0.0134389
# [100]	training's multi_logloss: 0.000193353	valid_1's multi_logloss: 0.0119987
# [110]	training's multi_logloss: 8.52511e-05	valid_1's multi_logloss: 0.0105771
# [120]	training's multi_logloss: 3.81372e-05	valid_1's multi_logloss: 0.0087915
# [130]	training's multi_logloss: 1.76204e-05	valid_1's multi_logloss: 0.00775428
# [140]	training's multi_logloss: 8.64779e-06	valid_1's multi_logloss: 0.00661959
# [150]	training's multi_logloss: 4.68873e-06	valid_1's multi_logloss: 0.00639962
# [160]	training's multi_logloss: 2.88465e-06	valid_1's multi_logloss: 0.00531592
# [170]	training's multi_logloss: 2.08088e-06	valid_1's multi_logloss: 0.00490318
# [180]	training's multi_logloss: 1.64517e-06	valid_1's multi_logloss: 0.00449728
# [190]	training's multi_logloss: 1.39991e-06	valid_1's multi_logloss: 0.00390131
# [200]	training's multi_logloss: 1.22904e-06	valid_1's multi_logloss: 0.00376446
# Early stopping, best iteration is:
# [199]	training's multi_logloss: 1.24299e-06	valid_1's multi_logloss: 0.00369751
# Fold 9 Score : 1.0
# Fold 10
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.532867	valid_1's multi_logloss: 0.782598
# [20]	training's multi_logloss: 0.201285	valid_1's multi_logloss: 0.520605
# [30]	training's multi_logloss: 0.079392	valid_1's multi_logloss: 0.437865
# [40]	training's multi_logloss: 0.0319873	valid_1's multi_logloss: 0.416967
# [50]	training's multi_logloss: 0.0130158	valid_1's multi_logloss: 0.426312
# Early stopping, best iteration is:
# [40]	training's multi_logloss: 0.0319873	valid_1's multi_logloss: 0.416967
# Fold 10 Score : 0.8369230769230769
# Fold 11
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.537069	valid_1's multi_logloss: 0.691709
# [20]	training's multi_logloss: 0.203566	valid_1's multi_logloss: 0.36688
# [30]	training's multi_logloss: 0.0806042	valid_1's multi_logloss: 0.228693
# [40]	training's multi_logloss: 0.032687	valid_1's multi_logloss: 0.163903
# [50]	training's multi_logloss: 0.0134995	valid_1's multi_logloss: 0.131346
# [60]	training's multi_logloss: 0.00564449	valid_1's multi_logloss: 0.114595
# [70]	training's multi_logloss: 0.00240266	valid_1's multi_logloss: 0.102575
# [80]	training's multi_logloss: 0.00103303	valid_1's multi_logloss: 0.100741
# [90]	training's multi_logloss: 0.000444382	valid_1's multi_logloss: 0.0996764
# [100]	training's multi_logloss: 0.000192712	valid_1's multi_logloss: 0.0969941
# [110]	training's multi_logloss: 8.53483e-05	valid_1's multi_logloss: 0.0944155
# [120]	training's multi_logloss: 3.80208e-05	valid_1's multi_logloss: 0.0935438
# [130]	training's multi_logloss: 1.74188e-05	valid_1's multi_logloss: 0.08761
# [140]	training's multi_logloss: 8.49987e-06	valid_1's multi_logloss: 0.0837303
# [150]	training's multi_logloss: 4.62756e-06	valid_1's multi_logloss: 0.0823511
# [160]	training's multi_logloss: 2.87318e-06	valid_1's multi_logloss: 0.0802075
# [170]	training's multi_logloss: 2.07367e-06	valid_1's multi_logloss: 0.0768522
# [180]	training's multi_logloss: 1.64408e-06	valid_1's multi_logloss: 0.076584
# [190]	training's multi_logloss: 1.39873e-06	valid_1's multi_logloss: 0.0753774
# [200]	training's multi_logloss: 1.22865e-06	valid_1's multi_logloss: 0.0739823
# [210]	training's multi_logloss: 1.10674e-06	valid_1's multi_logloss: 0.0724013
# [220]	training's multi_logloss: 1.02124e-06	valid_1's multi_logloss: 0.071735
# Early stopping, best iteration is:
# [216]	training's multi_logloss: 1.0502e-06	valid_1's multi_logloss: 0.0711026
# Fold 11 Score : 0.9719626168224299
# Fold 12
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.531368	valid_1's multi_logloss: 0.875959
# [20]	training's multi_logloss: 0.20037	valid_1's multi_logloss: 0.588846
# [30]	training's multi_logloss: 0.0788182	valid_1's multi_logloss: 0.412953
# [40]	training's multi_logloss: 0.0316468	valid_1's multi_logloss: 0.339226
# [50]	training's multi_logloss: 0.0129009	valid_1's multi_logloss: 0.308248
# [60]	training's multi_logloss: 0.00532635	valid_1's multi_logloss: 0.297295
# [70]	training's multi_logloss: 0.00223934	valid_1's multi_logloss: 0.301086
# Early stopping, best iteration is:
# [67]	training's multi_logloss: 0.00290012	valid_1's multi_logloss: 0.294433
# Fold 12 Score : 0.8958990536277602
# Fold 13
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.533883	valid_1's multi_logloss: 0.730493
# [20]	training's multi_logloss: 0.201662	valid_1's multi_logloss: 0.426628
# [30]	training's multi_logloss: 0.07922	valid_1's multi_logloss: 0.314746
# [40]	training's multi_logloss: 0.0317474	valid_1's multi_logloss: 0.267135
# [50]	training's multi_logloss: 0.0129108	valid_1's multi_logloss: 0.251769
# [60]	training's multi_logloss: 0.00533916	valid_1's multi_logloss: 0.250912
# Early stopping, best iteration is:
# [57]	training's multi_logloss: 0.00693651	valid_1's multi_logloss: 0.250007
# Fold 13 Score : 0.9105960264900662
# Fold 14
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.536553	valid_1's multi_logloss: 0.818147
# [20]	training's multi_logloss: 0.202031	valid_1's multi_logloss: 0.509353
# [30]	training's multi_logloss: 0.0799295	valid_1's multi_logloss: 0.351743
# [40]	training's multi_logloss: 0.0322354	valid_1's multi_logloss: 0.295664
# [50]	training's multi_logloss: 0.0131941	valid_1's multi_logloss: 0.257005
# [60]	training's multi_logloss: 0.00546993	valid_1's multi_logloss: 0.239675
# [70]	training's multi_logloss: 0.00230705	valid_1's multi_logloss: 0.236104
# [80]	training's multi_logloss: 0.000981722	valid_1's multi_logloss: 0.221909
# [90]	training's multi_logloss: 0.000418046	valid_1's multi_logloss: 0.216411
# [100]	training's multi_logloss: 0.000181068	valid_1's multi_logloss: 0.207515
# [110]	training's multi_logloss: 7.85921e-05	valid_1's multi_logloss: 0.211268
# Early stopping, best iteration is:
# [107]	training's multi_logloss: 0.000101182	valid_1's multi_logloss: 0.207008
# Fold 14 Score : 0.9337748344370861
# Fold 15
# Training until validation scores don't improve for 10 rounds
# [10]	training's multi_logloss: 0.532933	valid_1's multi_logloss: 0.803724
# [20]	training's multi_logloss: 0.201017	valid_1's multi_logloss: 0.55449
# [30]	training's multi_logloss: 0.0793142	valid_1's multi_logloss: 0.487413
# [40]	training's multi_logloss: 0.0319748	valid_1's multi_logloss: 0.486788
# Early stopping, best iteration is:
# [37]	training's multi_logloss: 0.0419563	valid_1's multi_logloss: 0.482114
# Fold 15 Score : 0.8809523809523809

# %%
importantce_df.head(10)
# Out:
#                           Fold 1                         Fold 2  \
# 0         53_tGravityAcc_min___X         53_tGravityAcc_min___X
# 1      58_tGravityAcc_energy___Y  38_tBodyAcc_correlation___X_Y
# 2  38_tBodyAcc_correlation___X_Y         51_tGravityAcc_max___Y
# 3         51_tGravityAcc_max___Y         54_tGravityAcc_min___Y
# 4        451_fBodyGyro_maxInds_Z        42_tGravityAcc_mean___Y
# 5          140_tBodyGyro_iqr___X        451_fBodyGyro_maxInds_Z
# 6     452_fBodyGyro_meanFreq___X        23_tBodyAcc_entropy___X
# 7          130_tBodyGyro_max___X           56_tGravityAcc_sma__
# 8        42_tGravityAcc_mean___Y           275_fBodyAcc_max___X
# 9          434_fBodyGyro_max___Y      58_tGravityAcc_energy___Y
#
#                             Fold 3                         Fold 4  \
# 0    38_tBodyAcc_correlation___X_Y         53_tGravityAcc_min___X
# 1        58_tGravityAcc_energy___Y  38_tBodyAcc_correlation___X_Y
# 2           53_tGravityAcc_min___X      58_tGravityAcc_energy___Y
# 3           51_tGravityAcc_max___Y         51_tGravityAcc_max___Y
# 4           54_tGravityAcc_min___Y        42_tGravityAcc_mean___Y
# 5  160_tBodyGyro_correlation___Y_Z          130_tBodyGyro_max___X
# 6            140_tBodyGyro_iqr___X      59_tGravityAcc_energy___Z
# 7       452_fBodyGyro_meanFreq___X          504_fBodyAccMag_std__
# 8     103_tBodyAccJerk_entropy___X     452_fBodyGyro_meanFreq___X
# 9            130_tBodyGyro_max___X        451_fBodyGyro_maxInds_Z
#
#                             Fold 5                           Fold 6  \
# 0           53_tGravityAcc_min___X    38_tBodyAcc_correlation___X_Y
# 1        58_tGravityAcc_energy___Y        58_tGravityAcc_energy___Y
# 2             275_fBodyAcc_max___X           53_tGravityAcc_min___X
# 3  160_tBodyGyro_correlation___Y_Z           54_tGravityAcc_min___Y
# 4          451_fBodyGyro_maxInds_Z           51_tGravityAcc_max___Y
# 5         559_angle_X_gravityMean_  160_tBodyGyro_correlation___Y_Z
# 6            130_tBodyGyro_max___X            504_fBodyAccMag_std__
# 7           54_tGravityAcc_min___Y          451_fBodyGyro_maxInds_Z
# 8          23_tBodyAcc_entropy___X            130_tBodyGyro_max___X
# 9            504_fBodyAccMag_std__             56_tGravityAcc_sma__
#
#                             Fold 7                           Fold 8  \
# 0    38_tBodyAcc_correlation___X_Y           53_tGravityAcc_min___X
# 1        58_tGravityAcc_energy___Y        58_tGravityAcc_energy___Y
# 2           53_tGravityAcc_min___X           51_tGravityAcc_max___Y
# 3          451_fBodyGyro_maxInds_Z    38_tBodyAcc_correlation___X_Y
# 4           51_tGravityAcc_max___Y          451_fBodyGyro_maxInds_Z
# 5  160_tBodyGyro_correlation___Y_Z  160_tBodyGyro_correlation___Y_Z
# 6            434_fBodyGyro_max___Y           54_tGravityAcc_min___Y
# 7           54_tGravityAcc_min___Y            130_tBodyGyro_max___X
# 8            504_fBodyAccMag_std__              10_tBodyAcc_max___X
# 9            506_fBodyAccMag_max__            506_fBodyAccMag_max__
#
#                             Fold 9                          Fold 10  \
# 0        58_tGravityAcc_energy___Y           53_tGravityAcc_min___X
# 1    38_tBodyAcc_correlation___X_Y    38_tBodyAcc_correlation___X_Y
# 2           53_tGravityAcc_min___X  160_tBodyGyro_correlation___Y_Z
# 3           51_tGravityAcc_max___Y          42_tGravityAcc_mean___Y
# 4  160_tBodyGyro_correlation___Y_Z          451_fBodyGyro_maxInds_Z
# 5          42_tGravityAcc_mean___Y            130_tBodyGyro_max___X
# 6       452_fBodyGyro_meanFreq___X        58_tGravityAcc_energy___Y
# 7            504_fBodyAccMag_std__            434_fBodyGyro_max___Y
# 8           54_tGravityAcc_min___Y            140_tBodyGyro_iqr___X
# 9            130_tBodyGyro_max___X              10_tBodyAcc_max___X
#
#                          Fold 11                        Fold 12  \
# 0         53_tGravityAcc_min___X         53_tGravityAcc_min___X
# 1  38_tBodyAcc_correlation___X_Y         54_tGravityAcc_min___Y
# 2        42_tGravityAcc_mean___Y  38_tBodyAcc_correlation___X_Y
# 3      58_tGravityAcc_energy___Y         51_tGravityAcc_max___Y
# 4         51_tGravityAcc_max___Y      58_tGravityAcc_energy___Y
# 5          140_tBodyGyro_iqr___X          504_fBodyAccMag_std__
# 6          130_tBodyGyro_max___X       559_angle_X_gravityMean_
# 7        451_fBodyGyro_maxInds_Z        42_tGravityAcc_mean___Y
# 8         54_tGravityAcc_min___Y   103_tBodyAccJerk_entropy___X
# 9     452_fBodyGyro_meanFreq___X        451_fBodyGyro_maxInds_Z
#
#                            Fold 13                          Fold 14  \
# 0           53_tGravityAcc_min___X        58_tGravityAcc_energy___Y
# 1    38_tBodyAcc_correlation___X_Y    38_tBodyAcc_correlation___X_Y
# 2  160_tBodyGyro_correlation___Y_Z           51_tGravityAcc_max___Y
# 3         559_angle_X_gravityMean_           53_tGravityAcc_min___X
# 4        58_tGravityAcc_energy___Y           54_tGravityAcc_min___Y
# 5          451_fBodyGyro_maxInds_Z          451_fBodyGyro_maxInds_Z
# 6           51_tGravityAcc_max___Y  160_tBodyGyro_correlation___Y_Z
# 7            504_fBodyAccMag_std__          42_tGravityAcc_mean___Y
# 8          42_tGravityAcc_mean___Y         559_angle_X_gravityMean_
# 9             275_fBodyAcc_max___X            130_tBodyGyro_max___X
#
#                            Fold 15
# 0    38_tBodyAcc_correlation___X_Y
# 1        58_tGravityAcc_energy___Y
# 2           53_tGravityAcc_min___X
# 3           54_tGravityAcc_min___Y
# 4            504_fBodyAccMag_std__
# 5  160_tBodyGyro_correlation___Y_Z
# 6          451_fBodyGyro_maxInds_Z
# 7          42_tGravityAcc_mean___Y
# 8           51_tGravityAcc_max___Y
# 9              10_tBodyAcc_max___X

# %%
# 元のラベルに戻すために1を足している
submit = np.argmax(np.mean(test_preds, axis=0), axis=1) + 1
np.savetxt('baseline.txt', submit)
